# %%
import importlib
import forest

importlib.reload(forest)
# Out:
# <module 'forest' from '/workspaces/immo-scraper/forest.py'>

# %%
from forest import *

# %%
soup = get_soup()

# %%
df = get_props()
df
# Out:
#            type    price  size  rooms  bed  \
# 0   Appartement   795000   117      5    3
# 1   Appartement   460000    75      3    2
# 2        Maison   940000   130      5    3
# 3   Appartement   510000    94      4    3
# 4   Appartement   539000    72      3    2
# 5   Appartement   299000    43      2    1
# 6   Appartement   265000    57      3    2
# 7   Appartement   200000    30      2    1
# 8   Appartement   650000   101      4    3
# 9        Maison   499000    74      4    2
# 10  Appartement   663000   108      5    3
# 11  Appartement   300000    66      2    1
# 12       Maison  1820000   185      8    5
#
#                                                  link
# 0   https://www.laforet.com/agence-immobiliere/meu...
# 1   https://www.laforet.com/agence-immobiliere/meu...
# 2   https://www.laforet.com/agence-immobiliere/meu...
# 3   https://www.laforet.com/agence-immobiliere/meu...
# 4   https://www.laforet.com/agence-immobiliere/meu...
# ...
